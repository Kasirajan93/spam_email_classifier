# %%
import joblib
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

# %%
X_train = joblib.load("X:/AI-SPAM-PHISHING-DETECTOR/models/X_train.pkl")
X_test = joblib.load("X:/AI-SPAM-PHISHING-DETECTOR/models/X_test.pkl")

y_train = joblib.load("X:/AI-SPAM-PHISHING-DETECTOR/models/y_train.pkl")
y_test = joblib.load("X:/AI-SPAM-PHISHING-DETECTOR/models/y_test.pkl")

# %%
lr = LogisticRegression(max_iter=1000)

lr.fit(X_train, y_train)

lr_pred = lr.predict(X_test)

# %%
print("Accuracy :", accuracy_score(y_test, lr_pred))
print("Precision:", precision_score(y_test, lr_pred))
print("Recall   :", recall_score(y_test, lr_pred))
print("F1 Score :", f1_score(y_test, lr_pred))

print("\nClassification Report\n")
print(classification_report(y_test, lr_pred))
# Out:
# Accuracy : 0.9573014517506405
# Precision: 0.9795918367346939
# Recall   : 0.8421052631578947
# F1 Score : 0.9056603773584906
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       886
#            1       0.98      0.84      0.91       285
#
#     accuracy                           0.96      1171
#    macro avg       0.97      0.92      0.94      1171
# weighted avg       0.96      0.96      0.96      1171

# %%
nb = MultinomialNB()

nb.fit(X_train, y_train)

nb_pred = nb.predict(X_test)

# %%
print("Accuracy :", accuracy_score(y_test, nb_pred))
print("Precision:", precision_score(y_test, nb_pred))
print("Recall   :", recall_score(y_test, nb_pred))
print("F1 Score :", f1_score(y_test, nb_pred))

print("\nClassification Report\n")
print(classification_report(y_test, nb_pred))
# Out:
# Accuracy : 0.9649871904355252
# Precision: 0.9586466165413534
# Recall   : 0.8947368421052632
# F1 Score : 0.925589836660617
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       886
#            1       0.96      0.89      0.93       285
#
#     accuracy                           0.96      1171
#    macro avg       0.96      0.94      0.95      1171
# weighted avg       0.96      0.96      0.96      1171

# %%
rf = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

rf.fit(X_train, y_train)

rf_pred = rf.predict(X_test)

# %%
print("Accuracy :", accuracy_score(y_test, rf_pred))
print("Precision:", precision_score(y_test, rf_pred))
print("Recall   :", recall_score(y_test, rf_pred))
print("F1 Score :", f1_score(y_test, rf_pred))

print("\nClassification Report\n")
print(classification_report(y_test, rf_pred))
# Out:
# Accuracy : 0.9615713065755764
# Precision: 0.9444444444444444
# Recall   : 0.8947368421052632
# F1 Score : 0.918918918918919
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       886
#            1       0.94      0.89      0.92       285
#
#     accuracy                           0.96      1171
#    macro avg       0.96      0.94      0.95      1171
# weighted avg       0.96      0.96      0.96      1171

# %%
results = pd.DataFrame({

    "Model":[
        "Logistic Regression",
        "Naive Bayes",
        "Random Forest"
    ],

    "Accuracy":[
        accuracy_score(y_test, lr_pred),
        accuracy_score(y_test, nb_pred),
        accuracy_score(y_test, rf_pred)
    ],

    "Precision":[
        precision_score(y_test, lr_pred),
        precision_score(y_test, nb_pred),
        precision_score(y_test, rf_pred)
    ],

    "Recall":[
        recall_score(y_test, lr_pred),
        recall_score(y_test, nb_pred),
        recall_score(y_test, rf_pred)
    ],

    "F1":[
        f1_score(y_test, lr_pred),
        f1_score(y_test, nb_pred),
        f1_score(y_test, rf_pred)
    ]

})

results.sort_values(
    by="Accuracy",
    ascending=False
)
# Out:
#                  Model  Accuracy  Precision    Recall        F1
# 1          Naive Bayes  0.964987   0.958647  0.894737  0.925590
# 2        Random Forest  0.961571   0.944444  0.894737  0.918919
# 0  Logistic Regression  0.957301   0.979592  0.842105  0.905660

# %%
joblib.dump(
    lr,
    "X:/AI-SPAM-PHISHING-DETECTOR/models/spam_classifier.pkl"
)

print("Best model saved successfully!")
# Out:
# Best model saved successfully!
